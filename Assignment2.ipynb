# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahabjan/ML-Workshop/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# 1. Create a Pandas DataFrame from the following dictionary:
# data = {
#  'Name': ['Alice', 'Bob', 'Carol'],
#  'Age': [24, 27, 22],
#  'Salary': [50000, 55000, 48000]
# }
# • Add a new column called Bonus which is 10% of the salary.

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Carol'],
    'Age': [24, 27, 22],
    'Salary': [50000, 55000, 48000]
}
df = pd.DataFrame(data)
df['Bonus'] = df['Salary'] * 0.10
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# 2. Given the DataFrame created in the above question:
# • Display the first two rows.
# • Compute the mean salary.

# %%
first_two_rows = df.head(2)
mean_salary = df['Salary'].mean()
print(first_two_rows)
print(mean_salary)
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 51000.0

# %% [markdown]
# 3. Using the same DataFrame:
# • Extract all rows where the Age is greater than 25.
# • Filter out rows where the Salary is less than 50000.

# %%
age_greater_than_25 = df[df['Age'] > 25]
salary_greater_than_50000 = df[df['Salary'] >= 50000]
print(age_greater_than_25)
print(salary_greater_than_50000)
# Out:
#   Name  Age  Salary   Bonus
# 1  Bob   27   55000  5500.0
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0

# %% [markdown]
# 4. Create the following DataFrame:
# data = {
#  'A': [1, 2, None, 4],
#  'B': [None, 2, 3, None],
#  'C': [1, 2, 3, 4]
# }
# df = pd.DataFrame(data)
# • Fill missing values in column A with the mean of the column.
# • Drop rows where all values are None.

# %%
import pandas as pd
data = {
    'A': [1, 2, None, 4],
    'B': [None, 2, 3, None],
    'C': [1, 2, 3, 4]
}
df = pd.DataFrame(data)
df['A'] = df['A'].fillna(df['A'].mean())
df = df.dropna(how='all')
print(df)
# Out:
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4

# %% [markdown]
# 5. Create a DataFrame for employees:
# data = {
#  'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
#  'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
#  'Salary': [50000, 45000, 60000, 65000, 70000]
# }
# • Group the data by Department and compute the total and mean salary for each
# department

# %%
import pandas as pd
data = {
    'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
    'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Salary': [50000, 45000, 60000, 65000, 70000]
}
df = pd.DataFrame(data)
salary_dept = df.groupby('Department')['Salary'].agg(['sum', 'mean'])
print(salary_dept)
# Out:
#                sum     mean
# Department
# Finance      70000  70000.0
# HR           95000  47500.0
# IT          125000  62500.0

# %% [markdown]
# 6. Given two DataFrames:
# df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
# df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
# • Perform an inner join on the ID column

# %%
import pandas as pd
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
result = pd.merge(df1, df2, on='ID', how='inner')
print(result)
# Out:
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# 7. Given a small dataset, clean and display basic statistics using Pandas.

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve', 'Alice'],
    'Age': [24, 27, 22, 32, None, 24],
    'Salary': [50000, 45000, 60000, 65000, 70000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR', 'HR']
}
df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
df = df.drop_duplicates()
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
print("\nCleaned DataFrame:")
print(df)
print("\nBasic Statistics:")
print(df.describe())
# Out:
# Original DataFrame:
#     Name   Age   Salary Department
# 0  Alice  24.0  50000.0         HR
# 1    Bob  27.0  45000.0         IT
# 2  Carol  22.0  60000.0         IT
# 3  David  32.0  65000.0    Finance
# 4    Eve   NaN  70000.0         HR
# 5  Alice  24.0      NaN         HR
#
# Cleaned DataFrame:
#     Name   Age   Salary Department
# 0  Alice  24.0  50000.0         HR
# 1    Bob  27.0  45000.0         IT
# 2  Carol  22.0  60000.0         IT
# 3  David  32.0  65000.0    Finance
# 4    Eve  25.8  70000.0         HR
# 5  Alice  24.0  58000.0         HR
#
# Basic Statistics:
#              Age        Salary
# count   6.000000      6.000000
# mean   25.800000  58000.000000
# std     3.487119   9273.618495
# min    22.000000  45000.000000
# 25%    24.000000  52000.000000
# 50%    24.900000  59000.000000
# 75%    26.700000  63750.000000
# max    32.000000  70000.000000

# %% [markdown]
# 8. small EDA task
# • Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.
# • Perform the following tasks:
# o Display the number of missing values in each column.
# o Find the average age of passengers.
# o Create a bar plot to show the survival rate based on gender

# %%
import matplotlib.pyplot as plt

# %%
df2=pd.read_csv('/content/Titanic-Dataset (1).csv')
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print("Missing values in each column:")
print(df2.isnull().sum())
# Out:
# Missing values in each column:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
average_age = df2['Age'].mean()
print(f"Average age of passengers: {average_age:.2f}")
# Out:
# Average age of passengers: 29.70

# %%
survival_rate_gender = df2.groupby('Sex')['Survived'].mean()

# %%
survival_rate_gender.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Survival Rate Based on Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 9. Data Transformation
# • Load a dataset containing daily temperatures and dates. Perform the following:
# o Convert the date column into a DateTime object.
# o Create a new column that categorizes temperatures into High, Medium, or
# Low

# %%
df.columns
# Out:
# Index(['Date', 'Temp'], dtype='object')

# %%
df3=pd.read_csv('/content/DailyDelhiClimateTrain.csv')
df3
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df3['date'] = pd.to_datetime(df3['date'])
def categorize_temperature(meantemp):
    if meantemp >= 30:
        return 'High'
    elif meantemp >= 15:
        return 'Medium'
    else:
        return 'Low'

df3['Temp_Category'] = df3['meantemp'].apply(categorize_temperature)

# Display the transformed data
print(df3.sample(10))
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure Temp_Category
# 401  2014-02-06  18.500000  65.375000    6.012500   1010.875000        Medium
# 194  2013-07-14  30.750000  71.625000    4.812500    997.375000          High
# 674  2014-11-06  23.000000  56.250000    6.250000   1011.625000        Medium
# 732  2015-01-03  15.125000  92.000000    0.925000   1017.375000        Medium
# 379  2014-01-15  12.000000  93.500000    0.462500   1019.750000           Low
# 687  2014-11-19  17.500000  58.125000    1.162500   1016.500000        Medium
# 1399 2016-10-31  24.538462  66.807692    1.642308   1017.807692        Medium
# 1388 2016-10-20  29.076923  47.730769    9.124000   1007.538462        Medium
# 115  2013-04-26  29.875000  45.875000    6.712500   1008.375000        Medium
# 1382 2016-10-14  29.750000  47.875000    8.934783   1009.125000        Medium
